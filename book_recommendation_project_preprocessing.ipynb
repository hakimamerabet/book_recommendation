# %%
import pandas as pd

# %%
data = pd.read_csv('datasets\books_data.csv')

# %%
data.head()
# Out:
#                                                Title  \
# 0                     Its Only Art If Its Well Hung!
# 1                           Dr. Seuss: American Icon
# 2              Wonderful Worship in Smaller Churches
# 3                      Whispers of the Wicked Saints
# 4  Nation Dance: Religion, Identity and Cultural ...
#
#                                          description              authors  \
# 0                                                NaN     ['Julie Strain']
# 1  Philip Nel takes a fascinating look into the k...       ['Philip Nel']
# 2  This resource includes twelve principles in un...     ['David R. Ray']
# 3  Julia Thomas finds her life spinning out of co...  ['Veronica Haddon']
# 4                                                NaN      ['Edward Long']
#
#                                                image  \
# 0  http://books.google.com/books/content?id=DykPA...
# 1  http://books.google.com/books/content?id=IjvHQ...
# 2  http://books.google.com/books/content?id=2tsDA...
# 3  http://books.google.com/books/content?id=aRSIg...
# 4                                                NaN
#
#                                          previewLink  publisher publishedDate  \
# 0  http://books.google.nl/books?id=DykPAAAACAAJ&d...        NaN          1996
# 1  http://books.google.nl/books?id=IjvHQsCn_pgC&p...  A&C Black    2005-01-01
# 2  http://books.google.nl/books?id=2tsDAAAACAAJ&d...        NaN          2000
# 3  http://books.google.nl/books?id=aRSIgJlq6JwC&d...  iUniverse       2005-02
# 4  http://books.google.nl/books?id=399SPgAACAAJ&d...        NaN    2003-03-01
#
#                                             infoLink  \
# 0  http://books.google.nl/books?id=DykPAAAACAAJ&d...
# 1  http://books.google.nl/books?id=IjvHQsCn_pgC&d...
# 2  http://books.google.nl/books?id=2tsDAAAACAAJ&d...
# 3  http://books.google.nl/books?id=aRSIgJlq6JwC&d...
# 4  http://books.google.nl/books?id=399SPgAACAAJ&d...
#
#                       categories  ratingsCount
# 0    ['Comics & Graphic Novels']           NaN
# 1  ['Biography & Autobiography']           NaN
# 2                   ['Religion']           NaN
# 3                    ['Fiction']           NaN
# 4                            NaN           NaN

# %%
# Basic stats
def basic_stats(dataframe):

    print("Display of dataset: ")
    display(dataframe.head())

    print("Basics statistics: ")
    display(dataframe.describe(include="all"))

    print("Percentage of missing values: ")
    display(100 * dataframe.isnull().sum() / dataframe.shape[0])

    print('Type for each columns')
    display(dataframe.dtypes)

    print(f"Dataframe shape : {dataframe.shape[0]} rows, {dataframe.shape[1]} columns")
    print()
    print('Count of duplicates rows :', len(dataframe)-len(dataframe.drop_duplicates()))
    print()

basic_stats(data)
# Out:
# Display of dataset:
#                                                Title  \
# 0                     Its Only Art If Its Well Hung!
# 1                           Dr. Seuss: American Icon
# 2              Wonderful Worship in Smaller Churches
# 3                      Whispers of the Wicked Saints
# 4  Nation Dance: Religion, Identity and Cultural ...
#
#                                          description              authors  \
# 0                                                NaN     ['Julie Strain']
# 1  Philip Nel takes a fascinating look into the k...       ['Philip Nel']
# 2  This resource includes twelve principles in un...     ['David R. Ray']
# 3  Julia Thomas finds her life spinning out of co...  ['Veronica Haddon']
# 4                                                NaN      ['Edward Long']
#
#                                                image  \
# 0  http://books.google.com/books/content?id=DykPA...
# 1  http://books.google.com/books/content?id=IjvHQ...
# 2  http://books.google.com/books/content?id=2tsDA...
# 3  http://books.google.com/books/content?id=aRSIg...
# 4                                                NaN
#
#                                          previewLink  publisher publishedDate  \
# 0  http://books.google.nl/books?id=DykPAAAACAAJ&d...        NaN          1996
# 1  http://books.google.nl/books?id=IjvHQsCn_pgC&p...  A&C Black    2005-01-01
# 2  http://books.google.nl/books?id=2tsDAAAACAAJ&d...        NaN          2000
# 3  http://books.google.nl/books?id=aRSIgJlq6JwC&d...  iUniverse       2005-02
# 4  http://books.google.nl/books?id=399SPgAACAAJ&d...        NaN    2003-03-01
#
#                                             infoLink  \
# 0  http://books.google.nl/books?id=DykPAAAACAAJ&d...
# 1  http://books.google.nl/books?id=IjvHQsCn_pgC&d...
# 2  http://books.google.nl/books?id=2tsDAAAACAAJ&d...
# 3  http://books.google.nl/books?id=aRSIgJlq6JwC&d...
# 4  http://books.google.nl/books?id=399SPgAACAAJ&d...
#
#                       categories  ratingsCount
# 0    ['Comics & Graphic Novels']           NaN
# 1  ['Biography & Autobiography']           NaN
# 2                   ['Religion']           NaN
# 3                    ['Fiction']           NaN
# 4                            NaN           NaN
# Basics statistics:
#                                  Title  \
# count                           212403
# unique                          212403
# top     Its Only Art If Its Well Hung!
# freq                                 1
# mean                               NaN
# std                                NaN
# min                                NaN
# 25%                                NaN
# 50%                                NaN
# 75%                                NaN
# max                                NaN
#
#                                               description        authors  \
# count                                              143962         180991
# unique                                             133226         127278
# top     Unlike some other reproductions of classic tex...  ['Rose Arny']
# freq                                                   92            236
# mean                                                  NaN            NaN
# std                                                   NaN            NaN
# min                                                   NaN            NaN
# 25%                                                   NaN            NaN
# 50%                                                   NaN            NaN
# 75%                                                   NaN            NaN
# max                                                   NaN            NaN
#
#                                                     image  \
# count                                              160329
# unique                                             149387
# top     http://books.google.com/books/content?id=7dMSA...
# freq                                                   79
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                               previewLink           publisher  \
# count                                              188568              136518
# unique                                             188099               16016
# top     http://books.google.com/books?id=acwPAgAAQBAJ&...  Simon and Schuster
# freq                                                   17                3454
# mean                                                  NaN                 NaN
# std                                                   NaN                 NaN
# min                                                   NaN                 NaN
# 25%                                                   NaN                 NaN
# 50%                                                   NaN                 NaN
# 75%                                                   NaN                 NaN
# max                                                   NaN                 NaN
#
#        publishedDate                                           infoLink  \
# count         187099                                             188568
# unique         11582                                             184506
# top             2000  https://play.google.com/store/books/details?id...
# freq            4286                                                 18
# mean             NaN                                                NaN
# std              NaN                                                NaN
# min              NaN                                                NaN
# 25%              NaN                                                NaN
# 50%              NaN                                                NaN
# 75%              NaN                                                NaN
# max              NaN                                                NaN
#
#          categories  ratingsCount
# count        171205  49752.000000
# unique        10883           NaN
# top     ['Fiction']           NaN
# freq          23419           NaN
# mean            NaN     21.252975
# std             NaN    201.340431
# min             NaN      1.000000
# 25%             NaN      1.000000
# 50%             NaN      2.000000
# 75%             NaN      5.000000
# max             NaN   4895.000000
# Percentage of missing values:
# Title             0.000471
# description      32.222557
# authors          14.789270
# image            24.516958
# previewLink      11.222011
# publisher        35.727199
# publishedDate    11.913617
# infoLink         11.222011
# categories       19.396527
# ratingsCount     76.576712
# dtype: float64
# Type for each columns
# Title             object
# description       object
# authors           object
# image             object
# previewLink       object
# publisher         object
# publishedDate     object
# infoLink          object
# categories        object
# ratingsCount     float64
# dtype: object
# Dataframe shape : 212404 rows, 10 columns
#
# Count of duplicates rows : 0

# %%
data.rename(columns={'Title': 'title'}, inplace=True)

# %%
data_test = data.dropna(subset=["title", "description", "authors", "image"])
data_test.shape
# Out:
# (135045, 10)

# %%
data_test2 = data.dropna(subset=["title", "description", "authors"])
data_test2.shape
# Out:
# (141755, 10)

# %%
data_test3 = data.dropna()
data_test3.shape
# Out:
# (40635, 10)

# %%
data["authors"]
# Out:
# 0                                ['Julie Strain']
# 1                                  ['Philip Nel']
# 2                                ['David R. Ray']
# 3                             ['Veronica Haddon']
# 4                                 ['Edward Long']
#                            ...
# 212399                        ['Elvira Woodruff']
# 212400                                        NaN
# 212401                      ['Wild Wild Cabbage']
# 212402                            ['Zadie Smith']
# 212403    ['David B. Johnson', 'Thomas A. Mowry']
# Name: authors, Length: 212404, dtype: object

# %%
data["categories"].value_counts()
# Out:
# categories
# ['Fiction']                               23419
# ['Religion']                               9459
# ['History']                                9330
# ['Juvenile Fiction']                       6643
# ['Biography & Autobiography']              6324
#                                           ...
# ['Authors, Japanese']                         1
# ['Birth certificates']                        1
# ['Restaurant management']                     1
# ['Oxford (England)']                          1
# ['Flame in the wind (Motion picture)']        1
# Name: count, Length: 10883, dtype: int64

# %%
data["categories"].value_counts().mean()
# Out:
# 15.731415969861251

# %%
pd.set_option("display.max_rows", None)
data["categories"].value_counts()[data["categories"].value_counts() > 100]
# Out:
# categories
# ['Fiction']                          23419
# ['Religion']                          9459
# ['History']                           9330
# ['Juvenile Fiction']                  6643
# ['Biography & Autobiography']         6324
# ['Business & Economics']              5625
# ['Computers']                         4312
# ['Social Science']                    3834
# ['Juvenile Nonfiction']               3446
# ['Science']                           2623
# ['Education']                         2611
# ['Cooking']                           2445
# ['Sports & Recreation']               2267
# ['Family & Relationships']            2178
# ['Literary Criticism']                2147
# ['Music']                             2106
# ['Medical']                           2079
# ['Art']                               2054
# ['Body, Mind & Spirit']               2049
# ['Language Arts & Disciplines']       2036
# ['Health & Fitness']                  2030
# ['Political Science']                 1955
# ['Psychology']                        1913
# ['Philosophy']                        1864
# ['Travel']                            1812
# ['Technology & Engineering']          1662
# ['Self-Help']                         1519
# ['Poetry']                            1500
# ['Foreign Language Study']            1404
# ['Crafts & Hobbies']                  1350
# ['Performing Arts']                   1305
# ['Reference']                         1277
# ['Mathematics']                       1185
# ['Comics & Graphic Novels']           1162
# ['Nature']                            1146
# ['Architecture']                       963
# ['Transportation']                     921
# ['Law']                                895
# ['Humor']                              799
# ['Photography']                        756
# ['American literature']                737
# ['Antiques & Collectibles']            697
# ['Drama']                              685
# ['Bible']                              667
# ['Pets']                               630
# ['Literary Collections']               607
# ['Young Adult Fiction']                595
# ['Games']                              545
# ['Gardening']                          532
# ['Study Aids']                         473
# ['Games & Activities']                 446
# ['House & Home']                       419
# ['English language']                   416
# ['Bibles']                             406
# ['United States']                      387
# ['True Crime']                         372
# ['Design']                             322
# ['Great Britain']                      268
# ["Children's stories"]                 252
# ['Detective and mystery stories']      235
# ['Animals']                            221
# ['Christian life']                     206
# ['Audiobooks']                         186
# ['African Americans']                  185
# ['World War, 1939-1945']               183
# ['English fiction']                    179
# ['Copyright']                          160
# ['American poetry']                    143
# ['American fiction']                   139
# ['Science fiction']                    130
# ['Children']                           126
# ['Adventure stories']                  122
# ['France']                             120
# ['Indians of North America']           118
# ['Conduct of life']                    114
# ['England']                            112
# ["Children's literature"]              107
# ['Frontier and pioneer life']          107
# ['Authors, American']                  107
# ['Books']                              104
# ['California']                         102
# ['Cats']                               101
# Name: count, dtype: int64

# %%
pd.reset_option("display.max_rows")

# %%
data = data.map(lambda x: x.replace('[', '').replace(']', '').replace("'", '') if isinstance(x, str) else x)
data.head()
# Out:
#                                                title  \
# 0                     Its Only Art If Its Well Hung!
# 1                           Dr. Seuss: American Icon
# 2              Wonderful Worship in Smaller Churches
# 3                      Whispers of the Wicked Saints
# 4  Nation Dance: Religion, Identity and Cultural ...
#
#                                          description          authors  \
# 0                                                NaN     Julie Strain
# 1  Philip Nel takes a fascinating look into the k...       Philip Nel
# 2  This resource includes twelve principles in un...     David R. Ray
# 3  Julia Thomas finds her life spinning out of co...  Veronica Haddon
# 4                                                NaN      Edward Long
#
#                                                image  \
# 0  http://books.google.com/books/content?id=DykPA...
# 1  http://books.google.com/books/content?id=IjvHQ...
# 2  http://books.google.com/books/content?id=2tsDA...
# 3  http://books.google.com/books/content?id=aRSIg...
# 4                                                NaN
#
#                                          previewLink  publisher publishedDate  \
# 0  http://books.google.nl/books?id=DykPAAAACAAJ&d...        NaN          1996
# 1  http://books.google.nl/books?id=IjvHQsCn_pgC&p...  A&C Black    2005-01-01
# 2  http://books.google.nl/books?id=2tsDAAAACAAJ&d...        NaN          2000
# 3  http://books.google.nl/books?id=aRSIgJlq6JwC&d...  iUniverse       2005-02
# 4  http://books.google.nl/books?id=399SPgAACAAJ&d...        NaN    2003-03-01
#
#                                             infoLink  \
# 0  http://books.google.nl/books?id=DykPAAAACAAJ&d...
# 1  http://books.google.nl/books?id=IjvHQsCn_pgC&d...
# 2  http://books.google.nl/books?id=2tsDAAAACAAJ&d...
# 3  http://books.google.nl/books?id=aRSIgJlq6JwC&d...
# 4  http://books.google.nl/books?id=399SPgAACAAJ&d...
#
#                   categories  ratingsCount
# 0    Comics & Graphic Novels           NaN
# 1  Biography & Autobiography           NaN
# 2                   Religion           NaN
# 3                    Fiction           NaN
# 4                        NaN           NaN

# %%
data["authors"].value_counts()
# Out:
# authors
# Rose Arny                                                                                                                 236
# William Shakespeare                                                                                                       191
# Library of Congress. Copyright Office                                                                                     178
# Agatha Christie                                                                                                           142
# Erle Stanley Gardner                                                                                                      124
#                                                                                                                          ...
# Robert E. Owens                                                                                                             1
# Mark Oliver Haroldsen                                                                                                       1
# John L. Esposito (international relations.), Director of the Center for Muslim-Christian Understanding John L Esposito      1
# Bernard Tschumi, Todd Gannon, Laurie A. Gunzelman, Jeffrey Kipnis                                                           1
# David B. Johnson, Thomas A. Mowry                                                                                           1
# Name: count, Length: 127275, dtype: int64
