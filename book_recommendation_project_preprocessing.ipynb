# %%
import pandas as pd

# %%
data = pd.read_csv('datasets/books_data.csv')

# %%
data.head()
# Out:
#                                                Title  \
# 0                     Its Only Art If Its Well Hung!
# 1                           Dr. Seuss: American Icon
# 2              Wonderful Worship in Smaller Churches
# 3                      Whispers of the Wicked Saints
# 4  Nation Dance: Religion, Identity and Cultural ...
#
#                                          description              authors  \
# 0                                                NaN     ['Julie Strain']
# 1  Philip Nel takes a fascinating look into the k...       ['Philip Nel']
# 2  This resource includes twelve principles in un...     ['David R. Ray']
# 3  Julia Thomas finds her life spinning out of co...  ['Veronica Haddon']
# 4                                                NaN      ['Edward Long']
#
#                                                image  \
# 0  http://books.google.com/books/content?id=DykPA...
# 1  http://books.google.com/books/content?id=IjvHQ...
# 2  http://books.google.com/books/content?id=2tsDA...
# 3  http://books.google.com/books/content?id=aRSIg...
# 4                                                NaN
#
#                                          previewLink  publisher publishedDate  \
# 0  http://books.google.nl/books?id=DykPAAAACAAJ&d...        NaN          1996
# 1  http://books.google.nl/books?id=IjvHQsCn_pgC&p...  A&C Black    2005-01-01
# 2  http://books.google.nl/books?id=2tsDAAAACAAJ&d...        NaN          2000
# 3  http://books.google.nl/books?id=aRSIgJlq6JwC&d...  iUniverse       2005-02
# 4  http://books.google.nl/books?id=399SPgAACAAJ&d...        NaN    2003-03-01
#
#                                             infoLink  \
# 0  http://books.google.nl/books?id=DykPAAAACAAJ&d...
# 1  http://books.google.nl/books?id=IjvHQsCn_pgC&d...
# 2  http://books.google.nl/books?id=2tsDAAAACAAJ&d...
# 3  http://books.google.nl/books?id=aRSIgJlq6JwC&d...
# 4  http://books.google.nl/books?id=399SPgAACAAJ&d...
#
#                       categories  ratingsCount
# 0    ['Comics & Graphic Novels']           NaN
# 1  ['Biography & Autobiography']           NaN
# 2                   ['Religion']           NaN
# 3                    ['Fiction']           NaN
# 4                            NaN           NaN

# %%
data.image[3]
# Out:
# 'http://books.google.com/books/content?id=aRSIgJlq6JwC&printsec=frontcover&img=1&zoom=1&source=gbs_api'

# %%
# Basic stats
def basic_stats(dataframe):

    print("Display of dataset: ")
    display(dataframe.head())

    print("Basics statistics: ")
    display(dataframe.describe(include="all"))

    print("Percentage of missing values: ")
    display(100 * dataframe.isnull().sum() / dataframe.shape[0])

    print('Type for each columns')
    display(dataframe.dtypes)

    print(f"Dataframe shape : {dataframe.shape[0]} rows, {dataframe.shape[1]} columns")
    print()
    print('Count of duplicates rows :', len(dataframe)-len(dataframe.drop_duplicates()))
    print()

basic_stats(data)
# Out:
# Display of dataset:
#                                                Title  \
# 0                     Its Only Art If Its Well Hung!
# 1                           Dr. Seuss: American Icon
# 2              Wonderful Worship in Smaller Churches
# 3                      Whispers of the Wicked Saints
# 4  Nation Dance: Religion, Identity and Cultural ...
#
#                                          description              authors  \
# 0                                                NaN     ['Julie Strain']
# 1  Philip Nel takes a fascinating look into the k...       ['Philip Nel']
# 2  This resource includes twelve principles in un...     ['David R. Ray']
# 3  Julia Thomas finds her life spinning out of co...  ['Veronica Haddon']
# 4                                                NaN      ['Edward Long']
#
#                                                image  \
# 0  http://books.google.com/books/content?id=DykPA...
# 1  http://books.google.com/books/content?id=IjvHQ...
# 2  http://books.google.com/books/content?id=2tsDA...
# 3  http://books.google.com/books/content?id=aRSIg...
# 4                                                NaN
#
#                                          previewLink  publisher publishedDate  \
# 0  http://books.google.nl/books?id=DykPAAAACAAJ&d...        NaN          1996
# 1  http://books.google.nl/books?id=IjvHQsCn_pgC&p...  A&C Black    2005-01-01
# 2  http://books.google.nl/books?id=2tsDAAAACAAJ&d...        NaN          2000
# 3  http://books.google.nl/books?id=aRSIgJlq6JwC&d...  iUniverse       2005-02
# 4  http://books.google.nl/books?id=399SPgAACAAJ&d...        NaN    2003-03-01
#
#                                             infoLink  \
# 0  http://books.google.nl/books?id=DykPAAAACAAJ&d...
# 1  http://books.google.nl/books?id=IjvHQsCn_pgC&d...
# 2  http://books.google.nl/books?id=2tsDAAAACAAJ&d...
# 3  http://books.google.nl/books?id=aRSIgJlq6JwC&d...
# 4  http://books.google.nl/books?id=399SPgAACAAJ&d...
#
#                       categories  ratingsCount
# 0    ['Comics & Graphic Novels']           NaN
# 1  ['Biography & Autobiography']           NaN
# 2                   ['Religion']           NaN
# 3                    ['Fiction']           NaN
# 4                            NaN           NaN
# Basics statistics:
#                                  Title  \
# count                           212403
# unique                          212403
# top     Its Only Art If Its Well Hung!
# freq                                 1
# mean                               NaN
# std                                NaN
# min                                NaN
# 25%                                NaN
# 50%                                NaN
# 75%                                NaN
# max                                NaN
#
#                                               description        authors  \
# count                                              143962         180991
# unique                                             133226         127278
# top     Unlike some other reproductions of classic tex...  ['Rose Arny']
# freq                                                   92            236
# mean                                                  NaN            NaN
# std                                                   NaN            NaN
# min                                                   NaN            NaN
# 25%                                                   NaN            NaN
# 50%                                                   NaN            NaN
# 75%                                                   NaN            NaN
# max                                                   NaN            NaN
#
#                                                     image  \
# count                                              160329
# unique                                             149387
# top     http://books.google.com/books/content?id=7dMSA...
# freq                                                   79
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                               previewLink           publisher  \
# count                                              188568              136518
# unique                                             188099               16016
# top     http://books.google.com/books?id=acwPAgAAQBAJ&...  Simon and Schuster
# freq                                                   17                3454
# mean                                                  NaN                 NaN
# std                                                   NaN                 NaN
# min                                                   NaN                 NaN
# 25%                                                   NaN                 NaN
# 50%                                                   NaN                 NaN
# 75%                                                   NaN                 NaN
# max                                                   NaN                 NaN
#
#        publishedDate                                           infoLink  \
# count         187099                                             188568
# unique         11582                                             184506
# top             2000  https://play.google.com/store/books/details?id...
# freq            4286                                                 18
# mean             NaN                                                NaN
# std              NaN                                                NaN
# min              NaN                                                NaN
# 25%              NaN                                                NaN
# 50%              NaN                                                NaN
# 75%              NaN                                                NaN
# max              NaN                                                NaN
#
#          categories  ratingsCount
# count        171205  49752.000000
# unique        10883           NaN
# top     ['Fiction']           NaN
# freq          23419           NaN
# mean            NaN     21.252975
# std             NaN    201.340431
# min             NaN      1.000000
# 25%             NaN      1.000000
# 50%             NaN      2.000000
# 75%             NaN      5.000000
# max             NaN   4895.000000
# Percentage of missing values:
# Title             0.000471
# description      32.222557
# authors          14.789270
# image            24.516958
# previewLink      11.222011
# publisher        35.727199
# publishedDate    11.913617
# infoLink         11.222011
# categories       19.396527
# ratingsCount     76.576712
# dtype: float64
# Type for each columns
# Title             object
# description       object
# authors           object
# image             object
# previewLink       object
# publisher         object
# publishedDate     object
# infoLink          object
# categories        object
# ratingsCount     float64
# dtype: object
# Dataframe shape : 212404 rows, 10 columns
#
# Count of duplicates rows : 0

# %%
data.rename(columns={'Title': 'title'}, inplace=True)

# %%
data = data.map(lambda x: x.replace('[', '').replace(']', '').replace("'", '') if isinstance(x, str) else x)
data.head(20)
# Out:
#                                                 title  \
# 0                      Its Only Art If Its Well Hung!
# 1                            Dr. Seuss: American Icon
# 2               Wonderful Worship in Smaller Churches
# 3                       Whispers of the Wicked Saints
# 4   Nation Dance: Religion, Identity and Cultural ...
# 5   The Church of Christ: A Biblical Ecclesiology ...
# 6                          The Overbury affair (Avon)
# 7             A Walk in the Woods: a Play in Two Acts
# 8                            Saint Hyacinth of Poland
# 9   Rising Sons and Daughters: Life Among Japans N...
# 10  Muslim Womens Choices: Religious Belief and So...
# 11                        Dramatica for Screenwriters
# 12   Mensa Number Puzzles (Mensa Word Games for Kids)
# 13  Vector Quantization and Signal Compression (Th...
# 14                               A husband for Kutani
# 15                                Gold and greenstone
# 16  The Ultimate Guide to Law School Admission: In...
# 17  The Repeal of Reticence: A History of Americas...
# 18  Overcoming Hypertension (Dr. Kenneth H. Cooper...
# 19                                   Alaska Sourdough
#
#                                           description  \
# 0                                                 NaN
# 1   Philip Nel takes a fascinating look into the k...
# 2   This resource includes twelve principles in un...
# 3   Julia Thomas finds her life spinning out of co...
# 4                                                 NaN
# 5   In The Church of Christ: A Biblical Ecclesiolo...
# 6                                                 NaN
# 7                                                 NaN
# 8   The story for children 10 and up of St. Hyacin...
# 9   Wardell recalls his experience as a foreign st...
# 10  Counters the Western views and stereotypes of ...
# 11  Dramatica for Screenwriters by Armando Saldana...
# 12  Acclaimed teacher and puzzler Evelyn B. Christ...
# 13  Herb Caen, a popular columnist for the San Fra...
# 14  First published in 1938, this is a collection ...
# 15  Sally did most things better than men but it w...
# 16  This collection brings together a distinguishe...
# 17  At a time when Americas faculties of taste and...
# 18  Like a time bomb ticking away, hypertension bu...
# 19  "Sourdough is a magical food", as author Ruth ...
#
#                                authors  \
# 0                         Julie Strain
# 1                           Philip Nel
# 2                         David R. Ray
# 3                      Veronica Haddon
# 4                          Edward Long
# 5                     Everett Ferguson
# 6                 Miriam Allen De Ford
# 7                         Lee Blessing
# 8                 Mary Fabyan Windeatt
# 9                       Steven Wardell
# 10  Camillia Fawzi El-Solh, Judy Mabro
# 11                Armando Salda A-Mora
# 12               Evelyn B. Christensen
# 13        Allen Gersho, Robert M. Gray
# 14                          Frank Owen
# 15                         Barry Crump
# 16                        Fiona Cownie
# 17                   Rochelle Gurstein
# 18                   Kenneth H. Cooper
# 19                         Ruth Allman
#
#                                                 image  \
# 0   http://books.google.com/books/content?id=DykPA...
# 1   http://books.google.com/books/content?id=IjvHQ...
# 2   http://books.google.com/books/content?id=2tsDA...
# 3   http://books.google.com/books/content?id=aRSIg...
# 4                                                 NaN
# 5   http://books.google.com/books/content?id=kVqRa...
# 6                                                 NaN
# 7                                                 NaN
# 8   http://books.google.com/books/content?id=lmLqA...
# 9                                                 NaN
# 10  http://books.google.com/books/content?id=o7izA...
# 11  http://books.google.com/books/content?id=iTueu...
# 12  http://books.google.com/books/content?id=tX1Is...
# 13  http://books.google.com/books/content?id=GgnrB...
# 14  http://books.google.com/books/content?id=EzxOD...
# 15                                                NaN
# 16  http://books.google.com/books/content?id=KAjcB...
# 17  http://books.google.com/books/content?id=6vYwC...
# 18  http://books.google.com/books/content?id=guP-e...
# 19  http://books.google.com/books/content?id=ubBQA...
#
#                                           previewLink  \
# 0   http://books.google.nl/books?id=DykPAAAACAAJ&d...
# 1   http://books.google.nl/books?id=IjvHQsCn_pgC&p...
# 2   http://books.google.nl/books?id=2tsDAAAACAAJ&d...
# 3   http://books.google.nl/books?id=aRSIgJlq6JwC&d...
# 4   http://books.google.nl/books?id=399SPgAACAAJ&d...
# 5   http://books.google.nl/books?id=kVqRaiPlx88C&p...
# 6   http://books.google.nl/books?id=mHLTngEACAAJ&d...
# 7   http://books.google.nl/books?id=6HDOwAEACAAJ&d...
# 8   http://books.google.nl/books?id=lmLqAAAACAAJ&d...
# 9   http://books.google.nl/books?id=rbLZugEACAAJ&d...
# 10  http://books.google.nl/books?id=o7izAAAAIAAJ&q...
# 11  http://books.google.nl/books?id=iTueuAAACAAJ&d...
# 12  http://books.google.nl/books?id=tX1IswEACAAJ&d...
# 13  http://books.google.nl/books?id=GgnrBwAAQBAJ&p...
# 14  http://books.google.nl/books?id=EzxODwAAQBAJ&p...
# 15  http://books.google.nl/books?id=I5NOAQAACAAJ&d...
# 16  http://books.google.nl/books?id=KAjcBAAAQBAJ&p...
# 17  http://books.google.nl/books?id=6vYwCwAAQBAJ&p...
# 18  http://books.google.nl/books?id=guP-e8igrK0C&p...
# 19  http://books.google.nl/books?id=ubBQAQAAIAAJ&q...
#
#                             publisher publishedDate  \
# 0                                 NaN          1996
# 1                           A&C Black    2005-01-01
# 2                                 NaN          2000
# 3                           iUniverse       2005-02
# 4                                 NaN    2003-03-01
# 5          Wm. B. Eerdmans Publishing          1996
# 6                                 NaN          1960
# 7                                 NaN          1988
# 8                     Tan Books & Pub    2009-01-01
# 9                  Plympton PressIntl          1995
# 10                   Berg Pub Limited    1994-02-17
# 11                                NaN       2005-07
# 12                           Sky Pony    2018-11-06
# 13  Springer Science & Business Media    2012-12-06
# 14         Pickle Partners Publishing    2018-02-27
# 15                                NaN          2009
# 16              Bloomsbury Publishing    2010-01-28
# 17                      Hill and Wang    2016-01-05
# 18                             Bantam    2012-02-01
# 19             Alaska Northwest Books          1976
#
#                                              infoLink  \
# 0   http://books.google.nl/books?id=DykPAAAACAAJ&d...
# 1   http://books.google.nl/books?id=IjvHQsCn_pgC&d...
# 2   http://books.google.nl/books?id=2tsDAAAACAAJ&d...
# 3   http://books.google.nl/books?id=aRSIgJlq6JwC&d...
# 4   http://books.google.nl/books?id=399SPgAACAAJ&d...
# 5   http://books.google.nl/books?id=kVqRaiPlx88C&d...
# 6   http://books.google.nl/books?id=mHLTngEACAAJ&d...
# 7   http://books.google.nl/books?id=6HDOwAEACAAJ&d...
# 8   http://books.google.nl/books?id=lmLqAAAACAAJ&d...
# 9   http://books.google.nl/books?id=rbLZugEACAAJ&d...
# 10  http://books.google.nl/books?id=o7izAAAAIAAJ&d...
# 11  http://books.google.nl/books?id=iTueuAAACAAJ&d...
# 12  http://books.google.nl/books?id=tX1IswEACAAJ&d...
# 13  https://play.google.com/store/books/details?id...
# 14  https://play.google.com/store/books/details?id...
# 15  http://books.google.nl/books?id=I5NOAQAACAAJ&d...
# 16  https://play.google.com/store/books/details?id...
# 17  https://play.google.com/store/books/details?id...
# 18  https://play.google.com/store/books/details?id...
# 19  http://books.google.nl/books?id=ubBQAQAAIAAJ&d...
#
#                    categories  ratingsCount
# 0     Comics & Graphic Novels           NaN
# 1   Biography & Autobiography           NaN
# 2                    Religion           NaN
# 3                     Fiction           NaN
# 4                         NaN           NaN
# 5                    Religion           5.0
# 6                         NaN           NaN
# 7                         NaN           3.0
# 8   Biography & Autobiography           NaN
# 9              Social Science           NaN
# 10                   Religion           NaN
# 11                  Reference           NaN
# 12        Juvenile Nonfiction           NaN
# 13   Technology & Engineering           NaN
# 14                    History           NaN
# 15        New Zealand fiction           NaN
# 16                        Law           NaN
# 17          Political Science           NaN
# 18           Health & Fitness           NaN
# 19                    Cooking           NaN

# %%
data = data.dropna(subset=["title", "description", "authors"])
data.head()
# Out:
#                                                title  \
# 1                           Dr. Seuss: American Icon
# 2              Wonderful Worship in Smaller Churches
# 3                      Whispers of the Wicked Saints
# 5  The Church of Christ: A Biblical Ecclesiology ...
# 8                           Saint Hyacinth of Poland
#
#                                          description               authors  \
# 1  Philip Nel takes a fascinating look into the k...            Philip Nel
# 2  This resource includes twelve principles in un...          David R. Ray
# 3  Julia Thomas finds her life spinning out of co...       Veronica Haddon
# 5  In The Church of Christ: A Biblical Ecclesiolo...      Everett Ferguson
# 8  The story for children 10 and up of St. Hyacin...  Mary Fabyan Windeatt
#
#                                                image  \
# 1  http://books.google.com/books/content?id=IjvHQ...
# 2  http://books.google.com/books/content?id=2tsDA...
# 3  http://books.google.com/books/content?id=aRSIg...
# 5  http://books.google.com/books/content?id=kVqRa...
# 8  http://books.google.com/books/content?id=lmLqA...
#
#                                          previewLink  \
# 1  http://books.google.nl/books?id=IjvHQsCn_pgC&p...
# 2  http://books.google.nl/books?id=2tsDAAAACAAJ&d...
# 3  http://books.google.nl/books?id=aRSIgJlq6JwC&d...
# 5  http://books.google.nl/books?id=kVqRaiPlx88C&p...
# 8  http://books.google.nl/books?id=lmLqAAAACAAJ&d...
#
#                     publisher publishedDate  \
# 1                   A&C Black    2005-01-01
# 2                         NaN          2000
# 3                   iUniverse       2005-02
# 5  Wm. B. Eerdmans Publishing          1996
# 8             Tan Books & Pub    2009-01-01
#
#                                             infoLink  \
# 1  http://books.google.nl/books?id=IjvHQsCn_pgC&d...
# 2  http://books.google.nl/books?id=2tsDAAAACAAJ&d...
# 3  http://books.google.nl/books?id=aRSIgJlq6JwC&d...
# 5  http://books.google.nl/books?id=kVqRaiPlx88C&d...
# 8  http://books.google.nl/books?id=lmLqAAAACAAJ&d...
#
#                   categories  ratingsCount
# 1  Biography & Autobiography           NaN
# 2                   Religion           NaN
# 3                    Fiction           NaN
# 5                   Religion           5.0
# 8  Biography & Autobiography           NaN

# %%
data.shape
# Out:
# (141755, 10)

# %% [markdown]
# from 212.403 books to 141.755 books after droping NaN values in most needed columns: title, authors, descriptions.

# %%
data.to_csv('books_preprocessed.csv', index=False)
